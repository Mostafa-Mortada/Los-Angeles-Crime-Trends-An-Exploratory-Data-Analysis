# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Dataset/crimes.csv")

# %%
df.head(10)
# Out:
#        DR_NO   Date Rptd    DATE OCC  TIME OCC    AREA NAME  \
# 0  220314085  2022-07-22  2020-05-12      1110    Southwest
# 1  222013040  2022-08-06  2020-06-04      1620      Olympic
# 2  220614831  2022-08-18  2020-08-17      1200    Hollywood
# 3  231207725  2023-02-27  2020-01-27       635  77th Street
# 4  220213256  2022-07-14  2020-07-14       900      Rampart
# 5  221216052  2022-07-07  2020-02-23      1000  77th Street
# 6  221515929  2022-10-10  2020-04-01      1200  N Hollywood
# 7  231906599  2023-03-03  2020-01-14      1335      Mission
# 8  231207476  2023-02-27  2020-08-15         1  77th Street
# 9  231506571  2023-03-03  2020-07-15      1700  N Hollywood
#
#                  Crm Cd Desc  Vict Age Vict Sex Vict Descent    Weapon Desc  \
# 0          THEFT OF IDENTITY        27        F            B            NaN
# 1          THEFT OF IDENTITY        60        M            H            NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185715 entries, 0 to 185714
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   DR_NO         185715 non-null  int64
#  1   Date Rptd     185715 non-null  object
#  2   DATE OCC      185715 non-null  object
#  3   TIME OCC      185715 non-null  int64
#  4   AREA NAME     185715 non-null  object
#  5   Crm Cd Desc   185715 non-null  object
#  6   Vict Age      185715 non-null  int64
#  7   Vict Sex      185704 non-null  object
#  8   Vict Descent  185705 non-null  object
#  9   Weapon Desc   73502 non-null   object
#  10  Status Desc   185715 non-null  object
#  11  LOCATION      185715 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 17.0+ MB

# %%
df.isnull().sum()
# Out:
# DR_NO                0
# Date Rptd            0
# DATE OCC             0
# TIME OCC             0
# AREA NAME            0
# Crm Cd Desc          0
# Vict Age             0
# Vict Sex            11
# Vict Descent        10
# Weapon Desc     112213
# Status Desc          0
# LOCATION             0
# dtype: int64

# %%
df['Vict Sex'] = df['Vict Sex'].fillna('Unknown')
df['Vict Descent'] = df['Vict Descent'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# DR_NO                0
# Date Rptd            0
# DATE OCC             0
# TIME OCC             0
# AREA NAME            0
# Crm Cd Desc          0
# Vict Age             0
# Vict Sex             0
# Vict Descent         0
# Weapon Desc     112213
# Status Desc          0
# LOCATION             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df['Vict Sex'].value_counts())
# Out:
# Vict Sex
# M          93008
# F          89854
# X           2812
# H             30
# Unknown       11
# Name: count, dtype: int64

# %%
df['Vict Sex'] = df['Vict Sex'].replace({'X': 'Not prefere to say', 'H': 'Not prefere to say'})

# %%
print(df['Vict Sex'].value_counts())
# Out:
# Vict Sex
# M                     93008
# F                     89854
# Not prefere to say     2842
# Unknown                  11
# Name: count, dtype: int64

# %%
df['Date Rptd'] = pd.to_datetime(df['Date Rptd'], errors='coerce')
df['DATE OCC'] = pd.to_datetime(df['DATE OCC'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185715 entries, 0 to 185714
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   DR_NO         185715 non-null  int64
#  1   Date Rptd     185715 non-null  datetime64[ns]
#  2   DATE OCC      185715 non-null  datetime64[ns]
#  3   TIME OCC      185715 non-null  int64
#  4   AREA NAME     185715 non-null  object
#  5   Crm Cd Desc   185715 non-null  object
#  6   Vict Age      185715 non-null  int64
#  7   Vict Sex      185715 non-null  object
#  8   Vict Descent  185715 non-null  object
#  9   Weapon Desc   73502 non-null   object
#  10  Status Desc   185715 non-null  object
#  11  LOCATION      185715 non-null  object
# dtypes: datetime64[ns](2), int64(3), object(7)
# memory usage: 17.0+ MB

# %% [markdown]
# After installing, you can import the library. It looks like you had a typo for `matplotlib` in cell `08BLQWrD2VRt`. I will correct that for you now.

# %%
df.head()
# Out:
#        DR_NO  Date Rptd   DATE OCC  TIME OCC    AREA NAME        Crm Cd Desc  \
# 0  220314085 2022-07-22 2020-05-12      1110    Southwest  THEFT OF IDENTITY
# 1  222013040 2022-08-06 2020-06-04      1620      Olympic  THEFT OF IDENTITY
# 2  220614831 2022-08-18 2020-08-17      1200    Hollywood  THEFT OF IDENTITY
# 3  231207725 2023-02-27 2020-01-27       635  77th Street  THEFT OF IDENTITY
# 4  220213256 2022-07-14 2020-07-14       900      Rampart  THEFT OF IDENTITY
#
#    Vict Age Vict Sex Vict Descent Weapon Desc  Status Desc  \
# 0        27        F            B         NaN  Invest Cont
# 1        60        M            H         NaN  Invest Cont
# 2        28        M            H         NaN  Invest Cont
# 3        37        M            H         NaN  Invest Cont
# 4        79        M            B         NaN  Invest Cont
#
#                                   LOCATION
# 0  2500 S  SYCAMORE                     AV
# 1  3300    SAN MARINO                   ST
# ...

# %%
df.describe()
# Out:
#               DR_NO                      Date Rptd  \
# count  1.857150e+05                         185715
# mean   2.255781e+08  2022-12-12 01:50:25.325902848
# min    2.009072e+08            2022-06-01 00:00:00
# 25%    2.210108e+08            2022-09-04 00:00:00
# 50%    2.220114e+08            2022-12-10 00:00:00
# 75%    2.310044e+08            2023-03-20 00:00:00
# max    2.399097e+08            2023-07-03 00:00:00
# std    5.017438e+06                            NaN
#
#                             DATE OCC       TIME OCC       Vict Age
# count                         185715  185715.000000  185715.000000
# mean   2022-11-27 19:04:55.711170560    1300.024414      39.999257
# min              2020-01-01 00:00:00       1.000000       2.000000
# 25%              2022-08-25 00:00:00     830.000000      28.000000
# 50%              2022-12-02 00:00:00    1340.000000      37.000000
# 75%              2023-03-12 00:00:00    1830.000000      50.000000
# ...

# %%
df['TIME OCC'] = df['TIME OCC'].astype(str).str.zfill(4)
df['TIME OCC'] = pd.to_datetime(df['TIME OCC'], format='%H%M').dt.time

# %%
df.head()
# Out:
#        DR_NO  Date Rptd   DATE OCC  TIME OCC    AREA NAME        Crm Cd Desc  \
# 0  220314085 2022-07-22 2020-05-12  11:10:00    Southwest  THEFT OF IDENTITY
# 1  222013040 2022-08-06 2020-06-04  16:20:00      Olympic  THEFT OF IDENTITY
# 2  220614831 2022-08-18 2020-08-17  12:00:00    Hollywood  THEFT OF IDENTITY
# 3  231207725 2023-02-27 2020-01-27  06:35:00  77th Street  THEFT OF IDENTITY
# 4  220213256 2022-07-14 2020-07-14  09:00:00      Rampart  THEFT OF IDENTITY
#
#    Vict Age Vict Sex Vict Descent Weapon Desc  Status Desc  \
# 0        27        F            B         NaN  Invest Cont
# 1        60        M            H         NaN  Invest Cont
# 2        28        M            H         NaN  Invest Cont
# 3        37        M            H         NaN  Invest Cont
# 4        79        M            B         NaN  Invest Cont
#
#                                   LOCATION
# 0  2500 S  SYCAMORE                     AV
# 1  3300    SAN MARINO                   ST
# ...

# %%
df['month'] = df['DATE OCC'].dt.month

# %%
df['year'] = df['DATE OCC'].dt.year

# %%
df['year'].value_counts().sort_index().plot(kind='bar')
plt.title('Crime Distribution by Year')
plt.xlabel('Year')
plt.ylabel('Number of Crimes')
plt.show()

# %%
df['month'].value_counts().sort_index().plot(kind='bar')
plt.title('Crime Distribution by Month')
plt.xlabel('Month')
plt.ylabel('Number of Crimes')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(y='Vict Descent', data=df, order=df['Vict Descent'].value_counts().index)

plt.title('Victim Descent Distribution')
plt.show()

# %%
color_map = {
    'M': 'cyan',
    'F': 'pink',
    'Unknown': 'yellow',
    'Not prefere to say': 'yellow',}

# %%
gender_counts = df['Vict Sex'].value_counts()
colors = [color_map.get(gender, 'gray') for gender in gender_counts.index]
gender_counts.plot(kind='bar', color=colors)

plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
# Top 10 areas with most crimes
top_areas = df['AREA NAME'].value_counts().head(10)

plt.figure(figsize=(10,5))
top_areas.plot(kind='bar')

plt.title('Top 10 Areas by Crime Count')
plt.xlabel('Area Name')
plt.ylabel('Number of Crimes')

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))

plt.hist(df['Vict Age'], bins=30, edgecolor='black')

plt.title('Distribution of Victim Age')
plt.xlabel('Age')
plt.ylabel('Number of Victims')

plt.tight_layout()
plt.show()
